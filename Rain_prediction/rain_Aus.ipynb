# %%
# https://www.analyticsvidhya.com/blog/2021/06/predictive-modelling-rain-prediction-in-australia-with-python/

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = 'weatherAUS.csv'

rain = pd.read_csv(dataset)

# %%
rain.shape
# Out:
# (145460, 23)

# %%
rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %%
rain.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
rain.describe(exclude=[object])
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
rain.describe(include=[object])
# Out:
#               Date  Location WindGustDir WindDir9am WindDir3pm RainToday  \
# count       145460    145460      135134     134894     141232    142199
# unique        3436        49          16         16         16         2
# top     2014-06-09  Canberra           W          N         SE        No
# freq            49      3436        9915      11758      10838    110319
#
#        RainTomorrow
# count        142193
# unique            2
# top              No
# freq         110316

# %%
categorical_features = [column_name for column_name in rain.columns if rain[column_name].dtype == 'O']

# %%
categorical_features
# Out:
# ['Date',
#  'Location',
#  'WindGustDir',
#  'WindDir9am',
#  'WindDir3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
numerical_features = [column_name for column_name in rain.columns if rain[column_name].dtype != 'O']

# %%
numerical_features
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
for each_feature in categorical_features:
   unique_values = len(rain[each_feature].unique())
   print("Cardinality(no. of unique values) of {} are: {}".format(each_feature, unique_values))
# Out:
# Cardinality(no. of unique values) of Date are: 3436
# Cardinality(no. of unique values) of Location are: 49
# Cardinality(no. of unique values) of WindGustDir are: 17
# Cardinality(no. of unique values) of WindDir9am are: 17
# Cardinality(no. of unique values) of WindDir3pm are: 17
# Cardinality(no. of unique values) of RainToday are: 3
# Cardinality(no. of unique values) of RainTomorrow are: 3

# %%
rain
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
rain['Date'] = pd.to_datetime(rain['Date'])
rain['year'] = rain['Date'].dt.year
rain['month'] = rain['Date'].dt.month
rain['day'] = rain['Date'].dt.day

# %%
rain.drop('Date', axis = 1, inplace = True)

# %%
categorical_features = [column_name for column_name in rain.columns if rain[column_name].dtype == 'O']
rain[categorical_features].isnull().sum()
# Out:
# Location            0
# WindGustDir     10326
# WindDir9am      10566
# WindDir3pm       4228
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
plt.bar(categorical_features, rain[categorical_features].isnull().sum())
plt.xticks(categorical_features, rotation='vertical', size=8)
plt.ylabel('No. of Null data')
plt.xlabel('Feature')
plt.show()

# %%
categorical_features_with_null = [feature for feature in categorical_features if rain[feature].isnull().sum()]

# %%
categorical_features_with_null
# Out:
# ['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
rain[categorical_features_with_null].isnull().sum()
# Out:
# WindGustDir     10326
# WindDir9am      10566
# WindDir3pm       4228
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
for each_feature in categorical_features_with_null:
    mode_val = rain[each_feature].mode()[0]
    rain[each_feature].fillna(mode_val,inplace=True)

# %%
rain[categorical_features_with_null].isnull().sum()
# Out:
# WindGustDir     0
# WindDir9am      0
# WindDir3pm      0
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %%
numerical_features = [column_name for column_name in rain.columns if rain[column_name].dtype != 'O']
rain[numerical_features].isnull().sum()
# Out:
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustSpeed    10263
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# year                 0
# month                0
# day                  0
# dtype: int64

# %%
plt.bar(numerical_features, rain[numerical_features].isnull().sum())
plt.xticks(numerical_features, rotation='vertical', size=8)
plt.ylabel('No. of Null data')
plt.xlabel('Feature')
plt.show()

# %%
for each_feature in numerical_features:
    print(rain[each_feature].quantile(0.25))
# Out:
# 7.6
# 17.9
# 0.0
# 2.6
# 4.8
# 31.0
# 7.0
# 13.0
# 57.0
# 37.0
# 1012.9
# 1010.4
# 1.0
# 2.0
# 12.3
# 16.6
# 2011.0
# 3.0
# 8.0

# %%
features_with_outliers = ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'WindGustSpeed','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']
for feature in features_with_outliers:
    q1 = rain[feature].quantile(0.25)
    q3 = rain[feature].quantile(0.75)
    IQR = q3-q1
    lower_limit = q1 - (IQR*1.5)
    upper_limit = q3 + (IQR*1.5)
    rain.loc[rain[feature]<lower_limit,feature] = lower_limit
    rain.loc[rain[feature]>upper_limit,feature] = upper_limit

# %%
numerical_features_with_null = [feature for feature in numerical_features if rain[feature].isnull().sum()]
for feature in numerical_features_with_null:
    mean_value = rain[feature].mean()
    rain[feature].fillna(mean_value,inplace=True)

# %%
rain[numerical_features]
# Out:
#         MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4  22.900000       0.6     5.318667  7.611178      44.000000
# 1           7.4  25.100000       0.0     5.318667  7.611178      44.000000
# 2          12.9  25.700000       0.0     5.318667  7.611178      46.000000
# 3           9.2  28.000000       0.0     5.318667  7.611178      24.000000
# 4          17.5  32.300000       1.0     5.318667  7.611178      41.000000
# ...         ...        ...       ...          ...       ...            ...
# 145455      2.8  23.400000       0.0     5.318667  7.611178      31.000000
# 145456      3.6  25.300000       0.0     5.318667  7.611178      22.000000
# 145457      5.4  26.900000       0.0     5.318667  7.611178      37.000000
# 145458      7.8  27.000000       0.0     5.318667  7.611178      28.000000
# 145459     14.9  23.224781       0.0     5.318667  7.611178      39.837792
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# ...              ...           ...          ...          ...          ...
# 145455          13.0          11.0         51.0         24.0       1024.6
# 145456          13.0           9.0         56.0         21.0       1023.5
# 145457           9.0           9.0         53.0         24.0       1021.0
# 145458          13.0           7.0         51.0         24.0       1019.4
# 145459          17.0          17.0         62.0         36.0       1020.2
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  year  month  day
# 0            1007.1  8.000000   4.50993     16.9     21.8  2008     12    1
# 1            1007.8  4.447461   4.50993     17.2     24.3  2008     12    2
# 2            1008.7  4.447461   2.00000     21.0     23.2  2008     12    3
# 3            1012.8  4.447461   4.50993     18.1     26.5  2008     12    4
# 4            1006.0  7.000000   8.00000     17.8     29.7  2008     12    5
# ...             ...       ...       ...      ...      ...   ...    ...  ...
# 145455       1020.3  4.447461   4.50993     10.1     22.4  2017      6   21
# 145456       1019.1  4.447461   4.50993     10.9     24.5  2017      6   22
# 145457       1016.8  4.447461   4.50993     12.5     26.1  2017      6   23
# 145458       1016.5  3.000000   2.00000     15.1     26.0  2017      6   24
# 145459       1017.9  8.000000   8.00000     15.0     20.9  2017      6   25
#
# [145460 rows x 19 columns]

# %%
categorical_features = [column_name for column_name in rain.columns if rain[column_name].dtype == 'O']
rain[categorical_features].isnull().sum()

# %%
numerical_features = [column_name for column_name in rain.columns if rain[column_name].dtype != 'O']
rain[numerical_features].isnull().sum()

# %%
rain['RainToday'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
rain['RainToday'].value_counts()
# Out:
# No     113580
# Yes     31880
# Name: RainToday, dtype: int64

# %%
rain['RainTomorrow'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
rain['RainTomorrow'].value_counts()
# Out:
# No     113583
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
import seaborn as sns

# %%
sns.lineplot(data=rain,x='Sunshine',y='Rainfall',color='green')
# Out:
# <AxesSubplot:xlabel='Sunshine', ylabel='Rainfall'>

# %%
sns.lineplot(data=rain,x='Sunshine',y='Evaporation',color='blue')
# Out:
# <AxesSubplot:xlabel='Sunshine', ylabel='Evaporation'>

# %%
def encode_data(feature_name):

    ''' 

    This function takes feature name as a parameter and returns mapping dictionary to replace(or map) categorical data with numerical data.

    '''

    mapping_dict = {}

    unique_values = list(rain[feature_name].unique())

    for idx in range(len(unique_values)):

        mapping_dict[unique_values[idx]] = idx

    return mapping_dict

# %%
rain['RainToday'].replace({'No':0, 'Yes': 1}, inplace = True)

rain['RainTomorrow'].replace({'No':0, 'Yes': 1}, inplace = True)

rain['WindGustDir'].replace(encode_data('WindGustDir'),inplace = True)

rain['WindDir9am'].replace(encode_data('WindDir9am'),inplace = True)

rain['WindDir3pm'].replace(encode_data('WindDir3pm'),inplace = True)

rain['Location'].replace(encode_data('Location'), inplace = True)

# %%
rain
# Out:
#         Location  MinTemp    MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0              0     13.4  22.900000       0.6     5.318667  7.611178
# 1              0      7.4  25.100000       0.0     5.318667  7.611178
# 2              0     12.9  25.700000       0.0     5.318667  7.611178
# 3              0      9.2  28.000000       0.0     5.318667  7.611178
# 4              0     17.5  32.300000       1.0     5.318667  7.611178
# ...          ...      ...        ...       ...          ...       ...
# 145455        48      2.8  23.400000       0.0     5.318667  7.611178
# 145456        48      3.6  25.300000       0.0     5.318667  7.611178
# 145457        48      5.4  26.900000       0.0     5.318667  7.611178
# 145458        48      7.8  27.000000       0.0     5.318667  7.611178
# 145459        48     14.9  23.224781       0.0     5.318667  7.611178
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  \
# 0                 0      44.000000           0           0  ...       1007.1
# 1                 1      44.000000           1           1  ...       1007.8
# 2                 2      46.000000           0           1  ...       1008.7
# 3                 3      24.000000           2           2  ...       1012.8
# 4                 0      41.000000           3           3  ...       1006.0
# ...             ...            ...         ...         ...  ...          ...
# 145455           14      31.000000           2           7  ...       1020.3
# 145456            4      22.000000           2          12  ...       1019.1
# 145457            5      37.000000           2           0  ...       1016.8
# 145458           12      28.000000           5          12  ...       1016.5
# 145459            0      39.837792          11           6  ...       1017.9
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  year  \
# 0       8.000000   4.50993     16.9     21.8          0             0  2008
# 1       4.447461   4.50993     17.2     24.3          0             0  2008
# 2       4.447461   2.00000     21.0     23.2          0             0  2008
# 3       4.447461   4.50993     18.1     26.5          0             0  2008
# 4       7.000000   8.00000     17.8     29.7          0             0  2008
# ...          ...       ...      ...      ...        ...           ...   ...
# 145455  4.447461   4.50993     10.1     22.4          0             0  2017
# 145456  4.447461   4.50993     10.9     24.5          0             0  2017
# 145457  4.447461   4.50993     12.5     26.1          0             0  2017
# 145458  3.000000   2.00000     15.1     26.0          0             0  2017
# 145459  8.000000   8.00000     15.0     20.9          0             0  2017
#
#         month  day
# 0          12    1
# 1          12    2
# 2          12    3
# 3          12    4
# 4          12    5
# ...       ...  ...
# 145455      6   21
# 145456      6   22
# 145457      6   23
# 145458      6   24
# 145459      6   25
#
# [145460 rows x 25 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(rain.corr(), linewidths=0.5, annot=False, fmt=".2f", cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
rain.corr()
# Out:
#                Location   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
#
# Humidity3pm        0.433179 -0.009463 -0.018568  0.012813
# Pressure9am       -0.229573  0.028290  0.034314 -0.019915
# Pressure3pm       -0.210585  0.023126  0.025093 -0.020277
# Cloud9am           0.249978  0.051533 -0.007930  0.005702
# Cloud3pm           0.298050  0.032182 -0.003046 -0.000555
# Temp9am           -0.025460  0.045687 -0.135289  0.000183
# Temp3pm           -0.187734  0.050555 -0.172732 -0.000271
# RainToday          0.305744 -0.014222  0.010441  0.003443
# RainTomorrow       1.000000 -0.014141  0.007674  0.005473
# year              -0.014141  1.000000 -0.112375 -0.005042
# month              0.007674 -0.112375  1.000000  0.009223
# day                0.005473 -0.005042  0.009223  1.000000
#
# [25 rows x 25 columns]

# %%
X = rain.drop(['RainTomorrow'],axis=1)
y = rain['RainTomorrow']

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 145455    0
# 145456    0
# 145457    0
# 145458    0
# 145459    0
# Name: RainTomorrow, Length: 145460, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
etr_model = ExtraTreesRegressor()
etr_model.fit(X,y)
etr_model.feature_importances_
# Out:
# array([0.03461524, 0.0298861 , 0.02894629, 0.04316886, 0.02303597,
#        0.0449874 , 0.02999877, 0.05652714, 0.03023196, 0.03181894,
#        0.03110919, 0.03243117, 0.03652085, 0.20271711, 0.0365689 ,
#        0.05007909, 0.02387107, 0.03499865, 0.02797576, 0.02827186,
#        0.04827822, 0.03089689, 0.03030872, 0.03275586])

# %%
feature_imp = pd.Series(etr_model.feature_importances_,index=X.columns)
feature_imp.nlargest(27).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
feature_imp.nlargest(23).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
feature_imp.nlargest(5).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)

# %%
X_train
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation   Sunshine  \
# 22926          7     18.8     23.7       0.2     5.000000   7.300000
# 80735         26      9.3     24.0       0.2     1.600000  10.900000
# 121764        40     10.9     22.2       1.4     1.200000   9.600000
# 139821        46     19.3     29.9       0.0     9.200000  11.000000
# 1867           0     15.7     17.6       2.0     5.318667   7.611178
# ...          ...      ...      ...       ...          ...        ...
# 41993         13     17.8     38.1       0.0    14.600000   7.611178
# 97639         32     12.5     27.3       0.0     5.318667  10.000000
# 95939         31     17.0     29.8       0.0     5.600000   7.611178
# 117952        39     11.9     22.0       2.0     6.200000   7.700000
# 43567         14     12.0     16.7       0.8     5.318667   7.611178
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure9am  \
# 22926            13           52.0          11           6  ...       1016.6
# 80735             3           48.0           1          14  ...       1018.3
# 121764            7           26.0           8          10  ...       1017.6
# 139821           13           43.0          11           2  ...       1015.9
# 1867             14           20.0          11           2  ...       1015.2
# ...             ...            ...         ...         ...  ...          ...
# 41993             3           39.0          15           2  ...       1014.5
# 97639             0           30.0           8           0  ...       1019.2
# 95939             8           22.0          13           7  ...       1019.6
# 117952           15           35.0           5           0  ...       1020.0
# 43567            15           50.0           6           5  ...       1032.0
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  year  \
# 22926        1013.9  5.000000   7.00000     21.4     22.2          0  2014
# 80735        1014.6  3.000000   5.00000     14.3     23.2          0  2016
# 121764       1014.9  1.000000   2.00000     16.6     21.5          1  2011
# 139821       1012.1  1.000000   1.00000     23.2     29.1          0  2010
# 1867         1010.5  8.000000   8.00000     16.5     17.3          1  2014
# ...             ...       ...       ...      ...      ...        ...   ...
# 41993        1009.7  1.000000   1.00000     25.4     36.8          0  2015
# 97639        1017.3  4.447461   4.50993     17.0     26.5          0  2012
# 95939        1016.1  4.447461   4.50993     24.1     29.0          0  2016
# 117952       1018.5  7.000000   6.00000     17.1     19.7          1  2009
# 43567        1032.2  4.447461   4.50993     14.7     16.4          0  2011
#
#         month  day
# 22926       3   12
# 80735      10    6
# 121764      8   31
# 139821      6   11
# 1867        4   10
# ...       ...  ...
# 41993      12   20
# 97639       3   11
# 95939       6   10
# 117952     11   20
# 43567      10   17
#
# [116368 rows x 24 columns]

# %%
print("Length of Training Data: {}".format(len(X_train)))
print("Length of Testing Data: {}".format(len(X_test)))
# Out:
# Length of Training Data: 116368
# Length of Testing Data: 29092

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-1.18585745,  1.03795338,  0.06904521, ...,  0.48571803,
#         -0.99114128, -0.42423541],
#        [ 0.17750331, -0.45434331,  0.11150037, ...,  1.27361887,
#          1.05239395, -1.10629435],
#        [ 1.18208492, -0.20300913, -0.14323059, ..., -0.69613322,
#          0.46852674,  1.7356179 ],
#        ...,
#        [ 0.53628245,  0.75520242,  0.93230012, ...,  1.27361887,
#         -0.11534047, -0.65158839],
#        [ 1.11032909, -0.04592527, -0.17153403, ..., -1.48403405,
#          1.34432755,  0.48517651],
#        [-0.68356665, -0.03021689, -0.92157518, ..., -0.69613322,
#          1.05239395,  0.14414704]])

# %%
from sklearn.linear_model import LogisticRegression
classifier_logreg = LogisticRegression(solver='liblinear', random_state=0)
classifier_logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %%
y_pred = classifier_logreg.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy Score: {}".format(accuracy_score(y_test,y_pred)))
# Out:
# Accuracy Score: 0.8444933315000688

# %%
print("Train Data Score: {}".format(classifier_logreg.score(X_train, y_train)))
print("Test Data Score: {}".format(classifier_logreg.score(X_test, y_test)))
# Out:
# Train Data Score: 0.8437714835693662
# Test Data Score: 0.8444933315000688

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[21536  1190]
#  [ 3334  3032]]

# %%
from sklearn.metrics import classification_report

# %%
target_names = ['No', 'Yes']

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.90     22726
#            1       0.72      0.48      0.57      6366
#
#     accuracy                           0.84     29092
#    macro avg       0.79      0.71      0.74     29092
# weighted avg       0.83      0.84      0.83     29092

# %%
print(classification_report(y_test, y_pred, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.95      0.90     22726
#          Yes       0.72      0.48      0.57      6366
#
#     accuracy                           0.84     29092
#    macro avg       0.79      0.71      0.74     29092
# weighted avg       0.83      0.84      0.83     29092

# %%
y_pred_logreg_proba = classifier_logreg.predict_proba(X_test)
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_logreg_proba[:,1])
plt.figure(figsize=(6,4))
plt.plot(fpr,tpr,'-g',linewidth=1)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve for Logistic Regression Model')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(classifier_logreg, X_train, y_train, cv = 5, scoring='accuracy')
print('Cross-validation scores:{}'.format(scores))
print('Average cross-validation score: {}'.format(scores.mean()))
# Out:
# Cross-validation scores:[0.84338747 0.84235628 0.84691072 0.84067374 0.84359558]
# Average cross-validation score: 0.8433847578355673
